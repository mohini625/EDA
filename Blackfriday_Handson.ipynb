# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Blackfridaydataset\\train.csv')

# %%
df.head(3)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
# User_ID                       550068 non-null int64
# Product_ID                    550068 non-null object
# Gender                        550068 non-null object
# Age                           550068 non-null object
# Occupation                    550068 non-null int64
# City_Category                 550068 non-null object
# Stay_In_Current_City_Years    550068 non-null object
# Marital_Status                550068 non-null int64
# Product_Category_1            550068 non-null int64
# Product_Category_2            376430 non-null float64
# Product_Category_3            166821 non-null float64
# Purchase                      550068 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
df.shape
# Out:
# (550068, 12)

# %%
df.Gender.value_counts()
# Out:
# M    414259
# F    135809
# Name: Gender, dtype: int64

# %%
df.Marital_Status.value_counts()
# Out:
# 0    324731
# 1    225337
# Name: Marital_Status, dtype: int64

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df.Product_Category_1.mean()
# Out:
# 5.404270017525106

# %%
df[['Product_Category_1','Product_Category_2','Product_Category_3']]
# Out:
#         Product_Category_1  Product_Category_2  Product_Category_3
# 0                        3                 NaN                 NaN
# 1                        1                 6.0                14.0
# 2                       12                 NaN                 NaN
# 3                       12                14.0                 NaN
# 4                        8                 NaN                 NaN
# 5                        1                 2.0                 NaN
# 6                        1                 8.0                17.0
# 7                        1                15.0                 NaN
# 8                        1                16.0                 NaN
# 9                        8                 NaN                 NaN
# 10                       5                11.0                 NaN
# 11                       8                 NaN                 NaN
# 12                       8                 NaN                 NaN
# ...

# %%
df[['Gender','Marital_Status','Purchase']].groupby(['Gender','Marital_Status']).sum()
# Out:
#                          Purchase
# Gender Marital_Status
# F      0                684154127
#        1                502078515
# M      0               2324773320
#        1               1584806780

# %%
684154127+2324773320
# Out:
# 3008927447

# %%
502078515+1584806780
# Out:
# 2086885295

# %%
df[['Marital_Status','Purchase']].groupby('Marital_Status').sum()
# Out:
#                   Purchase
# Marital_Status
# 0               3008927447
# 1               2086885295

# %%
df1 = df[['Gender','Age','Marital_Status','Purchase']].groupby(['Gender','Age','Marital_Status']).sum()

# %%
df1
# Out:
#                               Purchase
# Gender Age   Marital_Status
# F      0-17  0                42385978
#        18-25 0               155646801
#              1                49829041
#        26-35 0               258528663
#              1               184447570
#        36-45 0               150275279
#              1                93163684
#        46-50 0                27740352
#              1                88966512
#        51-55 0                32708873
#              1                56757124
#        55+   0                16868181
#              1                28914584
# M      0-17  0                92527205
#        18-25 0               568273801
#              1               140099032
#        26-35 0               974801439
#              1               613992906
#        36-45 0               473835481
#              1               309295440
#        46-50 0                85918008
#              1               218218531
# ...

# %%
df['Product_Category_2'].mode()
# Out:
# 0    8.0
# dtype: float64

# %%
df['Product_Category_2'].mode()[0]
# Out:
# 8.0
