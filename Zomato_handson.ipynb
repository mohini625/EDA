# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import os
cwd = os.getcwd()
print(cwd)

df = pd.read_csv('Zomatodataset\\zomato.csv')
# Out:
# C:\Users\mohin\1Python practice\Krish Naik

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
# Restaurant ID           9551 non-null int64
# Restaurant Name         9551 non-null object
# Country Code            9551 non-null int64
# City                    9551 non-null object
# Address                 9551 non-null object
# Locality                9551 non-null object
# Locality Verbose        9551 non-null object
# Longitude               9551 non-null float64
# Latitude                9551 non-null float64
# Cuisines                9542 non-null object
# Average Cost for two    9551 non-null int64
# Currency                9551 non-null object
# Has Table booking       9551 non-null object
# Has Online delivery     9551 non-null object
# Is delivering now       9551 non-null object
# Switch to order menu    9551 non-null object
# Price range             9551 non-null int64
# Aggregate rating        9551 non-null float64
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.isnull()
# Out:
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0             False            False         False  False    False     False
# 1             False            False         False  False    False     False
# 2             False            False         False  False    False     False
# 3             False            False         False  False    False     False
# 4             False            False         False  False    False     False
# 5             False            False         False  False    False     False
# 6             False            False         False  False    False     False
# 7             False            False         False  False    False     False
# 8             False            False         False  False    False     False
# 9             False            False         False  False    False     False
# 10            False            False         False  False    False     False
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
[x for x in df.columns if df[x].isnull().sum() > 0]
# Out:
# ['Cuisines']

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df[x]
# Out:
# 0                       French, Japanese, Desserts
# 1                                         Japanese
# 2                 Seafood, Asian, Filipino, Indian
# 3                                  Japanese, Sushi
# 4                                 Japanese, Korean
# 5                                          Chinese
# 6                                  Asian, European
# 7               Seafood, Filipino, Asian, European
# 8                          European, Asian, Indian
# 9                                         Filipino
# 10                               Filipino, Mexican
# 11                   American, Ice Cream, Desserts
# 12                               Filipino, Mexican
# 13                                        Filipino
# 14                                          Korean
# 15               Cafe, American, Italian, Filipino
# 16                                  Italian, Pizza
# 17                                        Filipino
# ...

# %%
#we can also use heatmap from seaborn library to detect the missing values visually
sns.heatmap(df.isnull())
#since there are around 9000 records, 9 missing(null) values of cuisines is not seen visisbly here

# %%
sns.heatmap(df.isnull(),yticklabels = False)

# %%
sns.heatmap(df.isnull(),yticklabels = False, cmap ='viridis')

# %%
df_country = pd.read_excel('Country-Code.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-f9dabc2c1526> in <module>()
# ----> 1 df_country = pd.read_excel('Country-Code.xlsx')
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ...

# %%
df_country = pd.read_excel('zomatodataset\\Country-Code.xlsx')

# %%
df_country.shape
# Out:
# (15, 2)

# %%
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
# Country Code    15 non-null int64
# Country         15 non-null object
# dtypes: int64(1), object(1)
# memory usage: 320.0+ bytes

# %%
df1=pd.merge(df,df_country,how = 'left')

# %%
df1.shape
# Out:
# (9551, 22)

# %%
df.shape
# Out:
# (9551, 21)

# %%
df1['Country'].isnull().sum()
# Out:
# 0

# %%
df1['Country'].value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# UAE                 60
# Brazil              60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
Cty_name = df1['Country'].value_counts().index

# %%
count = df1['Country'].value_counts().values

# %%
plt.pie(count[0:3],labels = Cty_name[0:3],autopct = '%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x259581d14e0>,
# ...
#  [Text(-1.08297,0.192787,'India'),
#   Text(1.07728,-0.222405,'United States'),
#   Text(1.09959,-0.0301578,'United Kingdom')],
#  [Text(-0.590713,0.105156,'94.39%'),
#   Text(0.587608,-0.121312,'4.73%'),
#   Text(0.599774,-0.0164497,'0.87%')])

# %% [markdown]
# Observation - ZOmato has maximum customer base in India followed by USA and UK respectively.

# %%
df1.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df1[['Restaurant ID','Country','Aggregate rating']]
# Out:
#       Restaurant ID      Country  Aggregate rating
# 0           6317637  Phillipines               4.8
# 1           6304287  Phillipines               4.5
# 2           6300002  Phillipines               4.4
# 3           6318506  Phillipines               4.9
# 4           6314302  Phillipines               4.8
# 5          18189371  Phillipines               4.4
# 6           6300781  Phillipines               4.0
# 7           6301290  Phillipines               4.2
# 8           6300010  Phillipines               4.9
# 9           6314987  Phillipines               4.8
# 10          6309903  Phillipines               4.9
# 11          6309455  Phillipines               4.2
# 12          6318433  Phillipines               4.8
# 13          6310470  Phillipines               4.2
# 14          6314605  Phillipines               4.3
# 15         18185059  Phillipines               3.6
# 16         18182702  Phillipines               4.0
# ...

# %%
df1.groupby(['Aggregate rating','Rating color','Rating text']).size()
# Out:
# Aggregate rating  Rating color  Rating text
# 0.0               White         Not rated      2148
# 1.8               Red           Poor              1
# 1.9               Red           Poor              2
# 2.0               Red           Poor              7
# 2.1               Red           Poor             15
# 2.2               Red           Poor             27
# 2.3               Red           Poor             47
# 2.4               Red           Poor             87
# 2.5               Orange        Average         110
# 2.6               Orange        Average         191
# 2.7               Orange        Average         250
# 2.8               Orange        Average         315
# 2.9               Orange        Average         381
# 3.0               Orange        Average         468
# 3.1               Orange        Average         519
# 3.2               Orange        Average         522
# 3.3               Orange        Average         483
# ...

# %%
df1.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index()
# Out:
#     Aggregate rating Rating color Rating text     0
# 0                0.0        White   Not rated  2148
# 1                1.8          Red        Poor     1
# 2                1.9          Red        Poor     2
# 3                2.0          Red        Poor     7
# 4                2.1          Red        Poor    15
# 5                2.2          Red        Poor    27
# 6                2.3          Red        Poor    47
# 7                2.4          Red        Poor    87
# 8                2.5       Orange     Average   110
# 9                2.6       Orange     Average   191
# 10               2.7       Orange     Average   250
# 11               2.8       Orange     Average   315
# 12               2.9       Orange     Average   381
# 13               3.0       Orange     Average   468
# 14               3.1       Orange     Average   519
# 15               3.2       Orange     Average   522
# 16               3.3       Orange     Average   483
# ...

# %%
ratings = df1.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns = {0:'Rating count'})

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# # observations
# Relation b/w aggregate rating and rating text is as follows-
# 4.5 - 4.9 -> Excellent
# 4.0 - 4.4 -> Very Good
# 3.5 - 3.9 -> Good
# 2.5 - 3.4 -> Average
# 1.8 - 2.4 -> Poor
# Maximun no(2148) of people have not rated.

# %%
sns.barplot(x='Aggregate rating',y='Rating count',data = ratings)

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(12,6)
#by default size is (width = 6.4,height = 4.8)

# %%
sns.barplot(x='Aggregate rating',y='Rating count',hue='Rating color',data = ratings,palette = ['blue','red','orange','yellow','green','green'])

# %%
#countplot
sns.countplot(x='Rating color',data=df)

# %%
df['Country']['aggregate rating' = 0]
# Out:
#   File "<ipython-input-125-04788a986d45>", line 1
#     df['Country']['aggregate rating' = 0]
#                                      ^
# SyntaxError: invalid syntax

# %%
df1[df1['Aggregate rating'] == 0]['Country'].reset_index().groupby('Country').sum().rename(columns = {'index': 'rated0 count'})
# Out:
#                 rated0 count
# Country
# Brazil                   312
# India               11769748
# United Kingdom          9351
# United States            889

# %%
df1.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines     ...       Has Table booking  \
# 0  French, Japanese, Desserts     ...                     Yes
# 1                    Japanese     ...                     Yes
#
# ...

# %%
df1[df1['Aggregate rating']==0]['Country'].reset_index()
# Out:
#       index         Country
# 0        30          Brazil
# 1        58          Brazil
# 2        69          Brazil
# 3        77          Brazil
# 4        78          Brazil
# 5       238   United States
# 6       239   United States
# 7       412   United States
# 8       871           India
# 9       872           India
# 10      873           India
# 11      874           India
# 12      878           India
# 13      879           India
# 14      880           India
# 15      887           India
# 16      888           India
# 17      889           India
# 18      897           India
# 19      899           India
# 20      900           India
# 21      901           India
# 22      902           India
# 23      903           India
# 24      904           India
# 25      905           India
# 26      906           India
# 27      907           India
# 28      908           India
# 29      912           India
# ...     ...             ...
# 2118   9008           India
# ...

# %%
df1.shape
# Out:
# (9551, 22)

# %%
df1[df1['Aggregate rating']==0]
# Out:
#       Restaurant ID              Restaurant Name  Country Code  \
# 30          6600060               Sandubas Cafí©            30
# 58          7305048        Quiosque Chopp Brahma            30
# 69          6710645             Cantinho da Gula            30
# 77          6701419                Divino Fogí£o            30
# 78          6703956                  Super Grill            30
# 238        18453427                  Frick's Tap           216
# 239        17793744                   Los Agaves           216
# 412        18491935                   Nosh Mahal           216
# 871            9299        Aggarwal Sweet Corner             1
# 872            9178        Kashyap Vaishno Dhaba             1
# 873        18477319             Total Food Court             1
# 874        18433852                The Chaiwalas             1
# 878        18377449                  Aapki Rasoi             1
# 879        18465871           Fusion Food Corner             1
# ...

# %%
df1[df1['Aggregate rating']==0].groupby('Country').size().reset_index().rename(columns = {0: 'rated0 count'})
# Out:
#           Country  rated0 count
# 0          Brazil             5
# 1           India          2139
# 2  United Kingdom             1
# 3   United States             3

# %%
df1.groupby(['Country','Currency']).size()
# Out:
# Country         Currency
# Australia       Dollar($)                   24
# Brazil          Brazilian Real(R$)          60
# Canada          Dollar($)                    4
# India           Indian Rupees(Rs.)        8652
# Indonesia       Indonesian Rupiah(IDR)      21
# New Zealand     NewZealand($)               40
# Phillipines     Botswana Pula(P)            22
# Qatar           Qatari Rial(QR)             20
# Singapore       Dollar($)                   20
# South Africa    Rand(R)                     60
# Sri Lanka       Sri Lankan Rupee(LKR)       20
# Turkey          Turkish Lira(TL)            34
# UAE             Emirati Diram(AED)          60
# United Kingdom  Pounds(Œ£)                  80
# United States   Dollar($)                  434
# dtype: int64

# %%
df1.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df1[df1['Has Online delivery'] == 'Yes'].groupby('Country').size()
# Out:
# Country
# India    2423
# UAE        28
# dtype: int64

# %%
df1[df1['Has Online delivery'] == 'Yes'].Country.value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %% [markdown]
# # Observation
# Online delivery option is available in only 2 countrie- Indai and UAE

# %%
#pie chart to show top5 cities distribution in terms of orders
df1.City.value_counts()
# Out:
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
# Lucknow               21
# Ahmedabad             21
# Bhubaneshwar          21
# Guwahati              21
# Amritsar              21
# Jaipur                20
# Athens                20
# Augusta               20
# Doha                  20
# Des Moines            20
# Dehradun              20
# Pocatello             20
# Rest of Hawaii        20
# Colombo               20
# Ludhiana              20
# Sharjah               20
# Edinburgh             20
# Albany                20
# Pune                  20
# Nashik                20
# Auckland              20
# Cape Town             20
# Ankara                20
# Dubuque               20
# Pensacola             20
#                     ...
# East Ballina           1
# Princeton              1
# Paynesville            1
# Ojo Caliente           1
# Palm Cove              1
# Macedon                1
# ...

# %%
City_Index= df1.City.value_counts().index

# %%
City_count=df1.City.value_counts().values

# %%
plt.pie(City_count[0:5],labels = City_Index[0:5],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2595d780a58>,
# ...
#  [Text(-0.614535,0.91233,'New Delhi'),
#   Text(0.0623675,-1.09823,'Gurgaon'),
#   Text(0.878905,-0.661458,'Noida'),
#   Text(1.09222,-0.130581,'Faridabad'),
#   Text(1.09995,-0.0108711,'Ghaziabad')],
#  [Text(-0.335201,0.497635,'68.87%'),
#   Text(0.0340187,-0.599035,'14.07%'),
#   Text(0.479402,-0.360795,'13.59%'),
#   Text(0.595757,-0.0712261,'3.16%'),
#   Text(0.599971,-0.0059297,'0.31%')])

# %% [markdown]
# # Observation:
# New Delhi stands first among the top 5 cities to have received most number of orders

# %%
#Find the top 10 cuisines
df1.Cuisines.value_counts()[0:10]
# Out:
# North Indian                      936
# North Indian, Chinese             511
# Fast Food                         354
# Chinese                           354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: Cuisines, dtype: int64

# %%
new=df1.Cuisines.str.split(',',expand = True).replace('None','')

# %%
new[0].value_counts()
# Out:
# North Indian         2992
# Chinese               855
# Fast Food             672
# Bakery                621
# Cafe                  617
# American              278
# South Indian          262
# Mithai                246
# Street Food           236
# Continental           235
# Italian               234
# Pizza                 232
# Mughlai               215
# Ice Cream             178
# Desserts              150
# Burger                116
# Biryani               112
# Raw Meats             110
# Beverages              79
# Finger Food            78
# Asian                  77
# Japanese               72
# European               62
# Mexican                62
# Healthy Food           56
# Indian                 51
# Seafood                49
# Thai                   29
# Mediterranean          28
# Lebanese               25
#                      ...
# African                 2
# New American            2
# Taiwanese               2
# Singaporean             2
# ...

# %%
new1= new[0].value_counts().append(new[1].value_counts()).append(new[2].value_counts())

# %%
new1.reset_index().groupby('index').size().str.
# Out:
# index
#  Afghani           2
#  African           1
#  American          2
#  Andhra            2
#  Arabian           2
#  Argentine         1
#  Armenian          1
#  Asian             2
#  Assamese          1
#  Australian        2
#  Awadhi            2
#  BBQ               2
#  Bakery            2
#  Bar Food          2
#  Belgian           1
#  Bengali           2
#  Beverages         2
#  Bihari            1
#  Biryani           2
#  Brazilian         2
#  Breakfast         1
#  British           2
#  Burger            2
#  Burmese           2
#  Bí_rek            1
#  Cafe              2
#  Cajun             2
#  Canadian          1
#  Cantonese         1
#  Caribbean         1
#                   ..
# Pub Food           1
# Rajasthani         1
# Ramen              1
# Raw Meats          1
# Restaurant Cafe    1
# Salad              1
# Sandwich           1
# Scottish           1
# Seafood            1
# Singaporean        1
# South American     1
# South Indian       1
# ...
